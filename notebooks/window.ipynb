# %%
import os.path
from os import path
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.callbacks import TensorBoard
from scripts.utils import *
import sklearn
from sklearn.model_selection import train_test_split
from tqdm import tqdm
from time import strftime

try:
    __import__("wget")
    import wget
    print("wget import exists")
    if(not path.exists("data")):
        print("Making Directory data")
        os.mkdir("data")   
    if(not path.exists("data/control.xls")):
        print("Downloading control.xls")
        wget.download("https://raw.githubusercontent.com/smithandrewk/sleep/main/data/control.xls","data/control.xls")
    if(not path.exists("data/deprivation.xls")):
        print("Downloading deprivation.xls")
        wget.download("https://raw.githubusercontent.com/smithandrewk/sleep/main/data/deprivation.xls","data/deprivation.xls")
    if(not path.exists("scripts")):
        print("Making Directory scripts")
        os.mkdir("scripts")   
    if(not path.exists("scripts/utils.py")):
        print("Downloading utils.py")
        wget.download("https://raw.githubusercontent.com/smithandrewk/sleep/main/scripts/utils.py","scripts/utils.py")
except ImportError:
    print("wget import does not exist, using python2.7 wget")
    if(not path.exists("data")):
        print("Making Directory data")
        # !mkdir data   
    if(not path.exists("data/control.xls")):
        print("control.xls not in data")
        # !wget -O data/control.xls https://raw.githubusercontent.com/smithandrewk/sleep/main/data/control.xls
    if(not path.exists("data/deprivation.xls")):
        print("deprivation.xls not in data")
        # !wget -O data/deprivation.xls https://raw.githubusercontent.com/smithandrewk/sleep/main/data/deprivation.xls
    if(not path.exists("scripts")):
        print("Making Directory scripts")
        # !mkdir scripts
    if(not path.exists("scripts/utils.py")):
        # !wget -O scripts/utils.py https://raw.githubusercontent.com/smithandrewk/sleep/main/scripts/utils.py
control = preprocess("control")
deprivation = preprocess("deprivation")
control_deprivation = pd.concat([control,deprivation])
control_deprivation.to_csv("data/controldeprivation_preprocessed.csv",index=False)
p,s,w = class_count(control)
p,s,w = class_count(deprivation)
p,s,w = class_count(control_deprivation)
# Out:
# wget import exists
# Examples:
#     Total: 8641
#     P: 367 (4.25% of total)
#     S: 3965 (45.89% of total)
#     W: 4309 (49.87% of total)
#
# Examples:
#     Total: 8641
#     P: 614 (7.11% of total)
#     S: 3294 (38.12% of total)
#     W: 4733 (54.77% of total)
#
# Examples:
#     Total: 17282
#     P: 981 (5.68% of total)
#     S: 7259 (42.00% of total)
#     W: 9042 (52.32% of total)

# %%
target_filename = 'controldeprivation' # or 'control' or 'deprivation'

# %%
df = pd.read_csv("data/"+target_filename+"_preprocessed.csv")

## Windowing
Y = pd.DataFrame()
for i in tqdm(range(len(df)-4)):
    win = df.iloc[i:i+5]
    c = np.argmax(np.bincount(win['Class']))
    del win['Class']
    x = win.values.flatten()
    x = np.insert(x,0,c)
    X = pd.DataFrame(x).T
    X = X.rename({0: 'Class'}, axis='columns')
    Y = pd.concat([Y,X])
df_win = Y
df_win = df_win.reset_index()
del df_win['index']
df_win['Class'] = df_win['Class'].astype(int)
df = df_win

df.to_csv("data/"+target_filename+"_windowed.csv",index=False)
# Out:
# 100%|██████████| 17278/17278 [04:16<00:00, 67.40it/s]

# %%
df = pd.read_csv("data/"+target_filename+"_windowed.csv")

## Balancing
# TODO : balancing algorithm
ps = df.loc[df["Class"]==0]
ss = df.loc[df["Class"]==1]
ws = df.loc[df["Class"]==2]
for i in range(int(w/p)):
  df = pd.concat([df,ps])
p,s,w = class_count(df)

df.to_csv("data/"+target_filename+"_windowed_balanced.csv",index=False)
# Out:
# Examples:
#     Total: 26116
#     P: 9820 (37.60% of total)
#     S: 7240 (27.72% of total)
#     W: 9056 (34.68% of total)

# %%
df = pd.read_csv("data/"+target_filename+"_windowed_balanced.csv")

# Use a utility from sklearn to split and shuffle our dataset.
train_df, test_df = train_test_split(df, test_size=0.2)
train_df, val_df = train_test_split(train_df, test_size=0.2)

# Form np arrays of labels and features.
train_labels = np.array(train_df.pop('Class'))
p_train_labels = train_labels == 0
s_train_labels = train_labels == 1
w_train_labels = train_labels == 2

val_labels = np.array(val_df.pop('Class'))
test_labels = np.array(test_df.pop('Class'))

train_features = np.array(train_df)
val_features = np.array(val_df)
test_features = np.array(test_df)
total = p + s + w
# Scaling by total/2 helps keep the loss to a similar magnitude.
# The sum of the weights of all examples stays the same.
weight_for_p = (1 / p)*(total)/2.0 
weight_for_w = (1 / w)*(total)/2.0
weight_for_s = (1 / s)*(total)/2.0


class_weight = {0: weight_for_p, 1: weight_for_s, 2: weight_for_w}

print('Weight for class 0: {:.2f}'.format(weight_for_p))
print('Weight for class 1: {:.2f}'.format(weight_for_s))
print('Weight for class 2: {:.2f}'.format(weight_for_w))
# Out:
# Weight for class 0: 1.33
# Weight for class 1: 1.80
# Weight for class 2: 1.44

# %%
def train(INPUT_FEATURES,hln=20,EPOCHS=100,BATCH_SIZE=200,weights=False):
    model = get_compiled_model(hln,INPUT_FEATURES=INPUT_FEATURES,dropout=True)
    """
    We one-hot encode the targets. Mathematically, this is good for calculating
    loss. CategoricalCrossEntropy simplifies to a negative log when targets are
    one-hot encoded. However, I simply recieved an error from model.fit when I 
    did not one-hot encode.
      @y : targets
      @depth : number of targets
    """
    # Callback choices
    plot_losses = TrainingPlot()
    early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor='categorical_accuracy', 
        verbose=1,
        patience=100,
        mode='max',
        restore_best_weights=True)
    tensorboard = TensorBoard(log_dir='logs/{}'.format(time()))
    if(weights):
        baseline_history = model.fit(
            train_features,
            tf.one_hot(train_labels,depth=3),
            batch_size=BATCH_SIZE,
            epochs=EPOCHS,
            validation_data=(val_features, tf.one_hot(val_labels,depth=3)),
            callbacks=[early_stopping],
            class_weight=class_weight)
    else:
        baseline_history = model.fit(
        train_features,
        tf.one_hot(train_labels,depth=3),
        batch_size=BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=(val_features, tf.one_hot(val_labels,depth=3)),
        callbacks=[early_stopping])
    train_predictions_baseline = model.predict(train_features, batch_size=BATCH_SIZE)
    test_predictions_baseline = model.predict(test_features, batch_size=BATCH_SIZE)
    baseline_results = model.evaluate(test_features, tf.one_hot(test_labels,depth=3),
                                      batch_size=BATCH_SIZE, verbose=0)
    plot_cm(tf.one_hot(test_labels,depth=3).numpy().argmax(axis=1),test_predictions_baseline.argmax(axis=1),baseline_results,hln)
    date = strftime('%X %x').replace("/","").split()
    plt.savefig("figures/"+str(date[1])+"@"+str(date[0][:5].replace(":",""))+"_"+str(hln)+".png",bbox_inches='tight')
    return baseline_history,baseline_results,date,model

# %%
train_history,test_history,date,model = train(INPUT_FEATURES=(train_features.shape[-1],),
                                   hln=200,
                                   EPOCHS=1000,
                                   weights=True)
# Out:
#  0.2985 - val_categorical_accuracy: 0.9426 - val_precision: 0.6228 - val_recall: 0.9220 - val_auc: 0.8536
# Epoch 321/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.2887 - categorical_accuracy: 0.9116 - precision: 0.5466 - recall: 0.8530 - auc: 0.7960 - val_loss: 0.2978 - val_categorical_accuracy: 0.9409 - val_precision: 0.6250 - val_recall: 0.8952 - val_auc: 0.8509
# Epoch 322/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.2899 - categorical_accuracy: 0.9052 - precision: 0.5528 - recall: 0.8305 - auc: 0.7897 - val_loss: 0.2904 - val_categorical_accuracy: 0.9435 - val_precision: 0.6118 - val_recall: 0.9280 - val_auc: 0.8523
# Epoch 323/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.2890 - categorical_accuracy: 0.9114 - precision: 0.5475 - recall: 0.8446 - auc: 0.7915 - val_loss: 0.2930 - val_categorical_accuracy: 0.9433 - val_precision: 0.6235 - val_recall: 0.8985 - val_auc: 0.8502
# Epoch 324/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.3028 - categorical_accuracy: 0.9112 - precision: 0.5447 - recall: 0.8366 - auc: 0.7886 - val_loss: 0.3019 - val_categorical_accuracy: 0.9445 - val_precision: 0.6094 - val_recall: 0.9313 - val_auc: 0.8486
# Epoch 325/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.3053 - categorical_accuracy: 0.9097 - precision: 0.5445 - recall: 0.8347 - auc: 0.7875 - val_loss: 0.3054 - val_categorical_accuracy: 0.9402 - val_precision: 0.6101 - val_recall: 0.8677 - val_auc: 0.8376
# Epoch 326/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.3177 - categorical_accuracy: 0.9043 - precision: 0.5386 - recall: 0.8287 - auc: 0.7818 - val_loss: 0.3158 - val_categorical_accuracy: 0.9433 - val_precision: 0.6287 - val_recall: 0.8861 - val_auc: 0.8519
# Epoch 327/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.3097 - categorical_accuracy: 0.9094 - precision: 0.5506 - recall: 0.8370 - auc: 0.7924 - val_loss: 0.3329 - val_categorical_accuracy: 0.9423 - val_precision: 0.6383 - val_recall: 0.8830 - val_auc: 0.8534
# Epoch 328/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.2929 - categorical_accuracy: 0.9137 - precision: 0.5520 - recall: 0.8292 - auc: 0.7913 - val_loss: 0.3167 - val_categorical_accuracy: 0.9450 - val_precision: 0.6359 - val_recall: 0.9007 - val_auc: 0.8545
# Epoch 329/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.2961 - categorical_accuracy: 0.9075 - precision: 0.5525 - recall: 0.8386 - auc: 0.7936 - val_loss: 0.2994 - val_categorical_accuracy: 0.9433 - val_precision: 0.6143 - val_recall: 0.9244 - val_auc: 0.8535
# Epoch 330/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.2897 - categorical_accuracy: 0.9061 - precision: 0.5496 - recall: 0.8613 - auc: 0.7984 - val_loss: 0.3200 - val_categorical_accuracy: 0.9378 - val_precision: 0.6216 - val_recall: 0.9119 - val_auc: 0.8505
# Epoch 331/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.3162 - categorical_accuracy: 0.9113 - precision: 0.5488 - recall: 0.8344 - auc: 0.7899 - val_loss: 0.3672 - val_categorical_accuracy: 0.9390 - val_precision: 0.6169 - val_recall: 0.9165 - val_auc: 0.8510
# Epoch 332/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.4959 - categorical_accuracy: 0.8990 - precision: 0.5422 - recall: 0.8389 - auc: 0.7859 - val_loss: 0.3123 - val_categorical_accuracy: 0.9407 - val_precision: 0.6209 - val_recall: 0.8634 - val_auc: 0.8422
# Epoch 333/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.3147 - categorical_accuracy: 0.8982 - precision: 0.5355 - recall: 0.8240 - auc: 0.7761 - val_loss: 0.2951 - val_categorical_accuracy: 0.9397 - val_precision: 0.6113 - val_recall: 0.8737 - val_auc: 0.8384
# Epoch 334/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.4227 - categorical_accuracy: 0.8987 - precision: 0.5396 - recall: 0.8228 - auc: 0.7792 - val_loss: 0.3049 - val_categorical_accuracy: 0.9407 - val_precision: 0.6162 - val_recall: 0.8823 - val_auc: 0.8423
# Epoch 335/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.3070 - categorical_accuracy: 0.9075 - precision: 0.5369 - recall: 0.8254 - auc: 0.7769 - val_loss: 0.2937 - val_categorical_accuracy: 0.9395 - val_precision: 0.6151 - val_recall: 0.8655 - val_auc: 0.8376
# Epoch 336/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.3189 - categorical_accuracy: 0.8985 - precision: 0.5335 - recall: 0.8278 - auc: 0.7734 - val_loss: 0.3034 - val_categorical_accuracy: 0.9414 - val_precision: 0.6105 - val_recall: 0.8935 - val_auc: 0.8398
# Epoch 337/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.3025 - categorical_accuracy: 0.9019 - precision: 0.5366 - recall: 0.8355 - auc: 0.7786 - val_loss: 0.2963 - val_categorical_accuracy: 0.9430 - val_precision: 0.6151 - val_recall: 0.8294 - val_auc: 0.8338
# Epoch 338/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.2927 - categorical_accuracy: 0.9062 - precision: 0.5390 - recall: 0.8066 - auc: 0.7712 - val_loss: 0.3111 - val_categorical_accuracy: 0.9466 - val_precision: 0.6252 - val_recall: 0.8617 - val_auc: 0.8439
# Epoch 339/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.3006 - categorical_accuracy: 0.9115 - precision: 0.5509 - recall: 0.8361 - auc: 0.7893 - val_loss: 0.3189 - val_categorical_accuracy: 0.9395 - val_precision: 0.6249 - val_recall: 0.8993 - val_auc: 0.8496
# Epoch 340/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.3035 - categorical_accuracy: 0.9042 - precision: 0.5519 - recall: 0.8314 - auc: 0.7863 - val_loss: 0.2951 - val_categorical_accuracy: 0.9390 - val_precision: 0.6230 - val_recall: 0.8799 - val_auc: 0.8427
# Epoch 341/1000
# 84/84 [==============================] - 1s 13ms/step - loss: 0.2798 - categorical_accuracy: 0.9045 - precision: 0.5501 - recall: 0.8253 - auc: 0.7867 - val_loss: 0.3145 - val_categorical_accuracy: 0.9380 - val_precision: 0.6256 - val_recall: 0.8595 - val_auc: 0.8424
# Epoch 342/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.3192 - categorical_accuracy: 0.9069 - precision: 0.5434 - recall: 0.8226 - auc: 0.7800 - val_loss: 0.2991 - val_categorical_accuracy: 0.9404 - val_precision: 0.6170 - val_recall: 0.8603 - val_auc: 0.8383
# Epoch 343/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.3329 - categorical_accuracy: 0.9046 - precision: 0.5456 - recall: 0.8148 - auc: 0.7774 - val_loss: 0.3186 - val_categorical_accuracy: 0.9419 - val_precision: 0.6254 - val_recall: 0.8674 - val_auc: 0.8450
# Epoch 344/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.2878 - categorical_accuracy: 0.9085 - precision: 0.5429 - recall: 0.8242 - auc: 0.7798 - val_loss: 0.3119 - val_categorical_accuracy: 0.9411 - val_precision: 0.6129 - val_recall: 0.8772 - val_auc: 0.8392
# Epoch 345/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.3138 - categorical_accuracy: 0.8959 - precision: 0.5423 - recall: 0.8163 - auc: 0.7793 - val_loss: 0.3031 - val_categorical_accuracy: 0.9404 - val_precision: 0.6056 - val_recall: 0.8969 - val_auc: 0.8428
# Epoch 346/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.2970 - categorical_accuracy: 0.9040 - precision: 0.5437 - recall: 0.8158 - auc: 0.7763 - val_loss: 0.2986 - val_categorical_accuracy: 0.9399 - val_precision: 0.6115 - val_recall: 0.8988 - val_auc: 0.8430
# Epoch 347/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.2929 - categorical_accuracy: 0.9058 - precision: 0.5444 - recall: 0.8212 - auc: 0.7823 - val_loss: 0.3101 - val_categorical_accuracy: 0.9450 - val_precision: 0.6228 - val_recall: 0.8722 - val_auc: 0.8410
# Epoch 348/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.2759 - categorical_accuracy: 0.9119 - precision: 0.5470 - recall: 0.8212 - auc: 0.7806 - val_loss: 0.2962 - val_categorical_accuracy: 0.9445 - val_precision: 0.6202 - val_recall: 0.8593 - val_auc: 0.8389
# Epoch 349/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.3150 - categorical_accuracy: 0.9003 - precision: 0.5444 - recall: 0.8063 - auc: 0.7759 - val_loss: 0.2879 - val_categorical_accuracy: 0.9452 - val_precision: 0.6225 - val_recall: 0.8629 - val_auc: 0.8388
# Epoch 350/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.7846 - categorical_accuracy: 0.9033 - precision: 0.5510 - recall: 0.8264 - auc: 0.7878 - val_loss: 0.2958 - val_categorical_accuracy: 0.9419 - val_precision: 0.6242 - val_recall: 0.9064 - val_auc: 0.8480
# Epoch 351/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.3693 - categorical_accuracy: 0.9047 - precision: 0.5458 - recall: 0.8305 - auc: 0.7860 - val_loss: 0.2895 - val_categorical_accuracy: 0.9419 - val_precision: 0.6145 - val_recall: 0.8212 - val_auc: 0.8335
# Epoch 352/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.3610 - categorical_accuracy: 0.9083 - precision: 0.5474 - recall: 0.7972 - auc: 0.7761 - val_loss: 0.3226 - val_categorical_accuracy: 0.9435 - val_precision: 0.6083 - val_recall: 0.8138 - val_auc: 0.8298
# Epoch 353/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.3314 - categorical_accuracy: 0.9102 - precision: 0.5463 - recall: 0.8082 - auc: 0.7768 - val_loss: 0.2888 - val_categorical_accuracy: 0.9440 - val_precision: 0.6115 - val_recall: 0.8047 - val_auc: 0.8314
# Epoch 354/1000
# 84/84 [==============================] - 1s 13ms/step - loss: 0.3102 - categorical_accuracy: 0.9066 - precision: 0.5388 - recall: 0.7973 - auc: 0.7672 - val_loss: 0.2960 - val_categorical_accuracy: 0.9421 - val_precision: 0.6078 - val_recall: 0.8567 - val_auc: 0.8325
# Epoch 355/1000
# 84/84 [==============================] - 1s 13ms/step - loss: 0.2971 - categorical_accuracy: 0.9012 - precision: 0.5397 - recall: 0.8143 - auc: 0.7708 - val_loss: 0.2992 - val_categorical_accuracy: 0.9414 - val_precision: 0.6134 - val_recall: 0.8050 - val_auc: 0.8324
# Epoch 356/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.3152 - categorical_accuracy: 0.9036 - precision: 0.5427 - recall: 0.7970 - auc: 0.7717 - val_loss: 0.2975 - val_categorical_accuracy: 0.9474 - val_precision: 0.6151 - val_recall: 0.8263 - val_auc: 0.8349
# Epoch 357/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.2889 - categorical_accuracy: 0.9058 - precision: 0.5431 - recall: 0.8074 - auc: 0.7743 - val_loss: 0.3062 - val_categorical_accuracy: 0.9445 - val_precision: 0.6162 - val_recall: 0.8437 - val_auc: 0.8366
# Epoch 358/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.2857 - categorical_accuracy: 0.9075 - precision: 0.5427 - recall: 0.8134 - auc: 0.7744 - val_loss: 0.3140 - val_categorical_accuracy: 0.9414 - val_precision: 0.6216 - val_recall: 0.8562 - val_auc: 0.8440
# Epoch 359/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.3042 - categorical_accuracy: 0.9048 - precision: 0.5442 - recall: 0.8196 - auc: 0.7773 - val_loss: 0.3184 - val_categorical_accuracy: 0.9378 - val_precision: 0.6163 - val_recall: 0.8768 - val_auc: 0.8397
# Epoch 360/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.3000 - categorical_accuracy: 0.9057 - precision: 0.5485 - recall: 0.8255 - auc: 0.7813 - val_loss: 0.3186 - val_categorical_accuracy: 0.9414 - val_precision: 0.6115 - val_recall: 0.8591 - val_auc: 0.8413
# Epoch 361/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.2929 - categorical_accuracy: 0.9050 - precision: 0.5454 - recall: 0.8179 - auc: 0.7788 - val_loss: 0.2860 - val_categorical_accuracy: 0.9392 - val_precision: 0.6161 - val_recall: 0.9007 - val_auc: 0.8484
# Epoch 362/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.2975 - categorical_accuracy: 0.9032 - precision: 0.5490 - recall: 0.8277 - auc: 0.7875 - val_loss: 0.2941 - val_categorical_accuracy: 0.9462 - val_precision: 0.6152 - val_recall: 0.8311 - val_auc: 0.8349
# Epoch 363/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.3299 - categorical_accuracy: 0.9099 - precision: 0.5498 - recall: 0.8101 - auc: 0.7811 - val_loss: 0.3000 - val_categorical_accuracy: 0.9419 - val_precision: 0.6153 - val_recall: 0.8631 - val_auc: 0.8398
# Epoch 364/1000
# 84/84 [==============================] - 1s 10ms/step - loss: 0.3000 - categorical_accuracy: 0.9025 - precision: 0.5373 - recall: 0.8084 - auc: 0.7708 - val_loss: 0.2990 - val_categorical_accuracy: 0.9404 - val_precision: 0.6112 - val_recall: 0.8720 - val_auc: 0.8405
# Epoch 365/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.3115 - categorical_accuracy: 0.9047 - precision: 0.5492 - recall: 0.8121 - auc: 0.7808 - val_loss: 0.3051 - val_categorical_accuracy: 0.9404 - val_precision: 0.6352 - val_recall: 0.8169 - val_auc: 0.8457
# Epoch 366/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.2934 - categorical_accuracy: 0.9082 - precision: 0.5593 - recall: 0.8043 - auc: 0.7852 - val_loss: 0.2998 - val_categorical_accuracy: 0.9416 - val_precision: 0.6204 - val_recall: 0.8674 - val_auc: 0.8452
# Epoch 367/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.2799 - categorical_accuracy: 0.9100 - precision: 0.5447 - recall: 0.8157 - auc: 0.7788 - val_loss: 0.3106 - val_categorical_accuracy: 0.9387 - val_precision: 0.6195 - val_recall: 0.9122 - val_auc: 0.8501
# Epoch 368/1000
# 84/84 [==============================] - 1s 10ms/step - loss: 0.2846 - categorical_accuracy: 0.9025 - precision: 0.5542 - recall: 0.8282 - auc: 0.7877 - val_loss: 0.2977 - val_categorical_accuracy: 0.9419 - val_precision: 0.6257 - val_recall: 0.8308 - val_auc: 0.8428
# Epoch 369/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.2765 - categorical_accuracy: 0.9051 - precision: 0.5556 - recall: 0.8063 - auc: 0.7838 - val_loss: 0.3001 - val_categorical_accuracy: 0.9399 - val_precision: 0.6172 - val_recall: 0.8997 - val_auc: 0.8461
# Epoch 370/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.3002 - categorical_accuracy: 0.8962 - precision: 0.5500 - recall: 0.8415 - auc: 0.7907 - val_loss: 0.3008 - val_categorical_accuracy: 0.9416 - val_precision: 0.6190 - val_recall: 0.8397 - val_auc: 0.8401
# Epoch 371/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.2879 - categorical_accuracy: 0.9053 - precision: 0.5544 - recall: 0.8099 - auc: 0.7832 - val_loss: 0.2929 - val_categorical_accuracy: 0.9399 - val_precision: 0.6081 - val_recall: 0.8155 - val_auc: 0.8321
# Epoch 372/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.2993 - categorical_accuracy: 0.9039 - precision: 0.5520 - recall: 0.8180 - auc: 0.7819 - val_loss: 0.3155 - val_categorical_accuracy: 0.9399 - val_precision: 0.6242 - val_recall: 0.8660 - val_auc: 0.8437
# Epoch 373/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.3067 - categorical_accuracy: 0.8958 - precision: 0.5437 - recall: 0.8080 - auc: 0.7749 - val_loss: 0.3217 - val_categorical_accuracy: 0.9407 - val_precision: 0.6226 - val_recall: 0.8469 - val_auc: 0.8412
# Epoch 374/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.3026 - categorical_accuracy: 0.8987 - precision: 0.5483 - recall: 0.8105 - auc: 0.7797 - val_loss: 0.3128 - val_categorical_accuracy: 0.9404 - val_precision: 0.6226 - val_recall: 0.8667 - val_auc: 0.8429
# Epoch 375/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.2872 - categorical_accuracy: 0.9022 - precision: 0.5494 - recall: 0.8206 - auc: 0.7856 - val_loss: 0.3054 - val_categorical_accuracy: 0.9380 - val_precision: 0.6269 - val_recall: 0.8485 - val_auc: 0.8431
# Epoch 376/1000
# 84/84 [==============================] - 1s 10ms/step - loss: 0.2777 - categorical_accuracy: 0.9052 - precision: 0.5530 - recall: 0.8295 - auc: 0.7874 - val_loss: 0.3180 - val_categorical_accuracy: 0.9404 - val_precision: 0.6194 - val_recall: 0.8650 - val_auc: 0.8430
# Epoch 377/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.2937 - categorical_accuracy: 0.8982 - precision: 0.5485 - recall: 0.8223 - auc: 0.7810 - val_loss: 0.3249 - val_categorical_accuracy: 0.9380 - val_precision: 0.6292 - val_recall: 0.8770 - val_auc: 0.8489
# Epoch 378/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.2822 - categorical_accuracy: 0.9012 - precision: 0.5512 - recall: 0.8160 - auc: 0.7831 - val_loss: 0.2910 - val_categorical_accuracy: 0.9399 - val_precision: 0.5988 - val_recall: 0.9093 - val_auc: 0.8396
# Epoch 379/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.3096 - categorical_accuracy: 0.8990 - precision: 0.5455 - recall: 0.8368 - auc: 0.7865 - val_loss: 0.3054 - val_categorical_accuracy: 0.9407 - val_precision: 0.6273 - val_recall: 0.8646 - val_auc: 0.8448
# Epoch 380/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.3132 - categorical_accuracy: 0.9038 - precision: 0.5455 - recall: 0.8131 - auc: 0.7806 - val_loss: 0.3272 - val_categorical_accuracy: 0.9426 - val_precision: 0.6305 - val_recall: 0.8533 - val_auc: 0.8467
# Epoch 381/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.7687 - categorical_accuracy: 0.9079 - precision: 0.5578 - recall: 0.8202 - auc: 0.7867 - val_loss: 0.3439 - val_categorical_accuracy: 0.9421 - val_precision: 0.6278 - val_recall: 0.8615 - val_auc: 0.8446
# Epoch 382/1000
# 84/84 [==============================] - 1s 12ms/step - loss: 0.2960 - categorical_accuracy: 0.9092 - precision: 0.5609 - recall: 0.8208 - auc: 0.7919 - val_loss: 0.3083 - val_categorical_accuracy: 0.9419 - val_precision: 0.6290 - val_recall: 0.8890 - val_auc: 0.8521
# Epoch 383/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.2820 - categorical_accuracy: 0.9057 - precision: 0.5525 - recall: 0.8335 - auc: 0.7917 - val_loss: 0.3012 - val_categorical_accuracy: 0.9409 - val_precision: 0.6277 - val_recall: 0.8938 - val_auc: 0.8493
# Epoch 384/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.2994 - categorical_accuracy: 0.8974 - precision: 0.5561 - recall: 0.8495 - auc: 0.7998 - val_loss: 0.3275 - val_categorical_accuracy: 0.9414 - val_precision: 0.6327 - val_recall: 0.8490 - val_auc: 0.8465
# Epoch 385/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.2754 - categorical_accuracy: 0.9130 - precision: 0.5575 - recall: 0.8046 - auc: 0.7868 - val_loss: 0.3125 - val_categorical_accuracy: 0.9433 - val_precision: 0.6300 - val_recall: 0.8801 - val_auc: 0.8494
# Epoch 386/1000
# 84/84 [==============================] - 1s 10ms/step - loss: 0.4132 - categorical_accuracy: 0.9091 - precision: 0.5596 - recall: 0.8216 - auc: 0.7931 - val_loss: 0.3100 - val_categorical_accuracy: 0.9421 - val_precision: 0.6202 - val_recall: 0.8883 - val_auc: 0.8507
# Epoch 387/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.2834 - categorical_accuracy: 0.9063 - precision: 0.5587 - recall: 0.8305 - auc: 0.7962 - val_loss: 0.3196 - val_categorical_accuracy: 0.9416 - val_precision: 0.6328 - val_recall: 0.8859 - val_auc: 0.8514
# Epoch 388/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.6854 - categorical_accuracy: 0.9041 - precision: 0.5571 - recall: 0.8218 - auc: 0.7899 - val_loss: 0.3205 - val_categorical_accuracy: 0.9440 - val_precision: 0.6303 - val_recall: 0.8382 - val_auc: 0.8419
# Epoch 389/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.3062 - categorical_accuracy: 0.9073 - precision: 0.5479 - recall: 0.8089 - auc: 0.7804 - val_loss: 0.3145 - val_categorical_accuracy: 0.9428 - val_precision: 0.6091 - val_recall: 0.8772 - val_auc: 0.8382
# Epoch 390/1000
# 84/84 [==============================] - 1s 11ms/step - loss: 0.2922 - categorical_accuracy: 0.9027 - precision: 0.5451 - recall: 0.8188 - auc: 0.7807 - val_loss: 0.3221 - val_categorical_accuracy: 0.9419 - val_precision: 0.6334 - val_recall: 0.8598 - val_auc: 0.8494
# Restoring model weights from the end of the best epoch.
# Epoch 00390: early stopping

# %%
model.save('./model')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-42fd1e53428d> in <module>
# ----> 1 model.save('./model')
#
# NameError: name 'model' is not defined

# %%
trains = []
tests = []
for i in range(5):
    train_history,test_history,date = train(INPUT_FEATURES=(train_features.shape[-1],),
                                   hln=200,
                                   EPOCHS=1000,
                                   weights=True)
    trains.append(train_history)
    tests.append(test_history)

# %%
plot_metrics(train_history)
plt.savefig("figures/"+str(date[1])+"@"+str(date[0][:5].replace(":",""))+"_training.png",bbox_inches='tight')
